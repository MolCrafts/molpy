# %%
import numpy as np
import xarray as xr

ds = xr.tutorial.load_dataset("air_temperature")
xr.set_options(display_expand_attrs=False, display_expand_data=False)
np.set_printoptions(threshold=10, edgeitems=2)

# %%
ds
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:  (lat: 25, time: 2920, lon: 53)
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float64 31MB 241.2 242.5 243.5 ... 296.2 295.7
# Attributes: (5)

# %%
ds["air"]
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 25, lon: 53)> Size: 31MB
# 241.2 242.5 243.5 244.0 244.1 243.9 ... 297.9 297.4 297.2 296.5 296.2 295.7
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Attributes: (11)

# %%
import pooch


file_path = pooch.retrieve(
    url="https://springernature.figshare.com/ndownloader/files/3195389",
    known_hash="3a63848ac80691bdb8d41834b575afad345b9300d7a2db0c38adb7f6eaa8360c"
)

# %%
from pooch import Untar
https://springernature.figshare.com/ndownloader/files/3195389
https://springernature.figshare.com/ndownloader/files/3195398

# %%
goodboy = pooch.create(
    path=pooch.os_cache("qm9"),
    base_url="https://springernature.figshare.com/ndownloader/files/",
    registry={
        "3195389": None,
        "3195368": None
    }
)

# %%
goodboy.fetch("dsgdb9nsd.xyz.tar.bz2")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 goodboy.fetch("dsgdb9nsd.xyz.tar.bz2")
#
# File /opt/conda/lib/python3.12/site-packages/pooch/core.py:589, in Pooch.fetch(self, fname, processor, downloader, progressbar)
#     586     if downloader is None:
#     587         downloader = choose_downloader(url, progressbar=progressbar)
# --> 589     stream_download(
#     590         url,
#     591         full_path,
#     592         known_hash,
#     593         downloader,
#     594         pooch=self,
#     595         retry_if_failed=self.retry_if_failed,
#     596     )
#     598 if processor is not None:
#     599     return processor(str(full_path), action, self)
#
# File /opt/conda/lib/python3.12/site-packages/pooch/core.py:807, in stream_download(url, fname, known_hash, downloader, pooch, retry_if_failed)
#     803 try:
# ...

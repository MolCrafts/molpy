# %% [markdown]
# # Force Field Parameters
#
# Detailed parameter management for force fields.
#
# ## Parameter Types
#
# - Nonbonded: LJ, Coulomb
# - Bonded: bonds, angles, dihedrals
#
# ## See Also
#
# - [Potential Overview](potential.ipynb)

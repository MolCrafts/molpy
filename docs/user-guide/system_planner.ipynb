# %% [markdown]
# # System Planner
#
# SystemPlanner generates complete polymer systems with target mass constraints. Top-level system planning guide.
#
# ## Table of Contents
#
# 1. [Overview](#overview)
# 2. [Basic Usage](#basic)
# 3. [Mass Constraints](#mass)
# 4. [Multi-Chain Systems](#multi-chain)

# %% [markdown]
# ## Overview
#
# ### Top Layer
#
# ```
# SystemPlanner  ← You are here
#   ↓
# PolydisperseChainGenerator
#   ↓
# SequenceGenerator
# ```
#
# ### Responsibility
#
# Generate chains until target mass reached.

# %%
# NOTE: This example is temporarily disabled due to API changes
# TODO: Update to current API

# from molpy.builder.polymer import SystemPlanner, PolydisperseChainGenerator, WeightedSequenceGenerator
# 
# seq_gen = WeightedSequenceGenerator(monomer_weights={'A': 1.0})
# chain_gen = PolydisperseChainGenerator(seq_gen, {'A': 100})
# 
# planner = SystemPlanner(chain_gen)
# plan = planner.plan_system(target_mass=100000, random_seed=42)
# 
# print(f'Chains: {len(plan.chains)}')
# print(f'Total: {plan.total_mass:.0f} g/mol')

# %% [markdown]
# ## See Also
#
# - [Polydisperse Chain Generator](polydisperse_chain_generator.ipynb)
# - [Polymer Builder Overview](polymer_builder_overview.ipynb)

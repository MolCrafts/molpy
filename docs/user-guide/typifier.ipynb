# %% [markdown]
# # Typifier: Rule-Based Atom Typing
#
# Typifier assigns force field types using SMARTS-based rules. Complete guide to atom typing.
#
# ## Table of Contents
#
# 1. [Overview](#overview)
# 2. [Basic Usage](#basic)
# 3. [Rule System](#rules)
# 4. [Priority](#priority)
# 5. [SMARTS Patterns](#smarts)

# %% [markdown]
# ## Overview
#
# ### What is Atom Typing?
#
# Assigning force field types to atoms based on chemical environment.
#
# **Why?** Required for molecular simulation.
#
# ### MolPy Approach
#
# SMARTS-based rules: pattern + type name.

# %%
# NOTE: This example is temporarily disabled due to API changes
# TODO: Update to current API

# from molpy.typifier import Typifier
# 
# typifier = Typifier()
# typifier.add_rule('CT', '[C;X4]', priority=1)
# typifier.add_rule('CA', '[c;r6]', priority=2)
# 
# print(f'Rules: {len(typifier.rules)}')

# %% [markdown]
# ## Priority System
#
# **Higher priority = checked first**
#
# Use for specific → general ordering.
#
# ### Best Practices
#
# - 100+: Very specific (functional groups)
# - 10-99: Moderately specific
# - 1-9: General (element only)

# %% [markdown]
# ## See Also
#
# - [Typifier Rules](typifier_rules.ipynb)
# - [Typifier SMARTS](typifier_smarts.ipynb)

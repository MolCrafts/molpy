# %% [markdown]
# # Data Formats
#
# Complete guide to reading and writing molecular structure files.
#
# ## Supported Formats
#
# - XYZ: Simple coordinates
# - PDB: Protein Data Bank
# - LAMMPS DATA: Full topology
# - GRO: GROMACS
# - MOL2: Tripos
#
# ## See Also
#
# - [IO Overview](io.ipynb)

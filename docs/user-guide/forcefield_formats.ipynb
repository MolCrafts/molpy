# %% [markdown]
# # Force Field Formats
#
# Reading and writing force field parameter files.
#
# ## Formats
#
# - XML: OpenMM-style
# - LAMMPS: LAMMPS parameter files
# - TOP: GROMACS topology
#
# ## See Also
#
# - [IO Overview](io.ipynb)

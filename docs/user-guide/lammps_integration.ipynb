# %% [markdown]
# # LAMMPS Integration
#
# Complete workflow for LAMMPS molecular dynamics simulations.
#
# ## Workflow
#
# 1. Build system
# 2. Assign atom types
# 3. Write LAMMPS DATA file
# 4. Run simulation
#
# ## See Also
#
# - [IO Overview](io.ipynb)
# - [Data Formats](data_formats.ipynb)

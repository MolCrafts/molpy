# %% [markdown]
# # Compute: Analysis Functions
#
# Trajectory analysis and property computation.
#
# ## Functions
#
# - RDF: Radial distribution function
# - MSD: Mean squared displacement
# - Time series analysis
#
# ## See Also
#
# - [Analysis Functions](analysis_functions.ipynb)

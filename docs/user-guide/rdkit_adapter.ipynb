# %% [markdown]
# # RDKit Adapter
#
# Bidirectional conversion between MolPy and RDKit structures.
#
# ## Functions
#
# - `sync_to_mol()`: MolPy → RDKit
# - `sync_from_mol()`: RDKit → MolPy
#
# ## See Also
#
# - [Adapter Overview](adapter.ipynb)

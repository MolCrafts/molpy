# %% [markdown]
# # Typifier Rules
#
# Detailed guide to typifier rule system and SMARTS patterns.
#
# ## Overview
#
# Rules map SMARTS patterns to force field types.
#
# ## See Also
#
# - [Typifier](typifier.ipynb)
# - [Typifier SMARTS](typifier_smarts.ipynb)

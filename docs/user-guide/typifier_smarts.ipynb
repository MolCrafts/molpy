# %% [markdown]
# # Typifier SMARTS Patterns
#
# Common SMARTS patterns for force field atom typing.
#
# ## Overview
#
# SMARTS patterns for OPLS-AA, AMBER, CHARMM force fields.
#
# ## See Also
#
# - [Typifier](typifier.ipynb)
# - [Typifier Rules](typifier_rules.ipynb)

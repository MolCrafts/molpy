# %% [markdown]
# # Analysis Functions
#
# Detailed guide to trajectory analysis functions.
#
# ## Available Analyses
#
# - `compute_rdf()`: Pair correlation
# - `compute_msd()`: Diffusion
# - Time series functions
#
# ## See Also
#
# - [Compute Overview](compute.ipynb)

# %% [markdown]
# # External Tools Integration
#
# Integration with AmberTools, Packmol, OpenMM.
#
# ## Supported Tools
#
# - AmberTools: Force field assignment
# - Packmol: System packing
# - OpenMM: MD simulations
#
# ## See Also
#
# - [Adapter Overview](adapter.ipynb)

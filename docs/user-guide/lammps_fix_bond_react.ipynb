# %% [markdown]
# # LAMMPS fix bond/react
#
# Generating LAMMPS fix bond/react templates for reactive MD.
#
# ## Overview
#
# Create reaction templates for LAMMPS reactive simulations.
#
# ## See Also
#
# - [Potential Overview](potential.ipynb)

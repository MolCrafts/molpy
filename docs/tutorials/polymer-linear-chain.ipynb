# %% [markdown]
# # Building Polymers with CGSmiles and PolymerBuilder
#
# This notebook demonstrates building polymers with different topologies:
# - **Linear chains**: `{[#EO2]|4[#PS]}`
# - **Cyclic (ring) structures**: `{[#EO2]1[#PS][#EO2][#PS][#EO2]1}`
# - **Branched structures**: `{[#PS][#EO3]([#PS])([#PS])}` (requires 3-arm monomer)

# %% [markdown]
# ## Step 1: Import Libraries

# %%
import numpy as np
import molpy as mp
from molpy.core.atomistic import Atomistic
from molpy.external import RDKitAdapter, Generate3D
from molpy.parser.smiles import bigsmilesir_to_polymerspec, parse_bigsmiles, parse_cgsmiles
from molpy.reacter import Reacter, select_hydroxyl_group, form_single_bond
from molpy.reacter.selectors import select_port_atom
from molpy.reacter.utils import find_neighbors
from molpy.builder.polymer.connectors import ReacterConnector
from molpy.builder.polymer.placer import CovalentSeparator, LinearOrienter, Placer
from molpy.builder.polymer import PolymerBuilder
from molpy.builder.polymer.port_utils import get_all_port_info
from molpy.typifier.atomistic import OplsAtomisticTypifier
from molpy.io.data.lammps import LammpsDataWriter
from pathlib import Path

# %% [markdown]
# ## Step 2: Load Force Field

# %%
ff = mp.io.read_xml_forcefield("oplsaa.xml")
typifier = OplsAtomisticTypifier(ff, strict_typing=False)
print("✅ Force field loaded")
# Out:
# /workspaces/molcrafts/molpy/src/molpy/potential/dihedral/opls.py:91: UserWarning: RB coefficients do not lie on the ideal 4-term OPLS manifold (C0+C1+C2+C3+C4 = 10.041600, expected ≈ 0). Conversion will preserve forces and relative energies exactly, but will introduce a constant energy offset of ΔE = 10.041600 kJ/mol. This does not affect MD simulations.
#   warnings.warn(
# ✅ Force field loaded

# %% [markdown]
# ## Step 3: Build Monomers
#
# Build three types of monomers using symmetric `$` ports (all ports are equivalent):
# 1. **EO2** (linear): 2 ports using `[$]`
# 2. **PS** (linear): 2 ports using `[$]`
# 3. **EO3** (3-arm): 3 ports using `[$]`

# %%
def build_monomer_from_bigsmiles(bigsmiles: str, typifier):
    """Build monomer from BigSMILES with 3D coordinates."""
    ir = parse_bigsmiles(bigsmiles)
    polymerspec = bigsmilesir_to_polymerspec(ir)
    monomers = polymerspec.all_monomers()
    if len(monomers) != 1:
        raise ValueError(f"Expected 1 monomer, got {len(monomers)}")
    
    monomer = monomers[0]
    adapter = RDKitAdapter(internal=monomer)
    generate_3d = Generate3D(add_hydrogens=True, embed=True, optimize=True, update_internal=True)
    adapter = generate_3d(adapter)
    monomer = adapter.get_internal()
    monomer.get_topo(gen_angle=True, gen_dihe=True)
    
    for idx, atom in enumerate(monomer.atoms):
        atom["id"] = idx + 1
    
    typifier.typify(monomer)

    return monomer

# Build linear monomers
eo2 = build_monomer_from_bigsmiles("{[$]OCCO[$]}", typifier)
ps = build_monomer_from_bigsmiles("{[$]OCC(c1ccccc1)CO[$]}", typifier)

# Build 3-arm monomer using BigSMILES
eo3 = build_monomer_from_bigsmiles("{[$]OCC(CO[$])(CO[$])}", typifier)

print("✅ Monomers built:")
print(f"   EO2: {len(eo2.atoms)} atoms, ports: {list(get_all_port_info(eo2).keys())}")
print(f"   PS: {len(ps.atoms)} atoms, ports: {list(get_all_port_info(ps).keys())}")
print(f"   EO3: {len(eo3.atoms)} atoms, ports: {list(get_all_port_info(eo3).keys())}")

# Verify EO3 has 3 ports for branching
eo3_ports = list(get_all_port_info(eo3).keys())
if len(eo3_ports) < 3:
    print(f"⚠️  WARNING: EO3 only has {len(eo3_ports)} port(s): {eo3_ports}")
    print("   BigSMILES format may not support multiple descriptors in parentheses.")
    print("   Consider using atom class notation or manually marking ports.")
# Out:
# ✅ Monomers built:
#    EO2: 10 atoms, ports: ['$']
#    PS: 29 atoms, ports: ['$']
#    EO3: 17 atoms, ports: ['$']
# ⚠️  WARNING: EO3 only has 1 port(s): ['$']
#    BigSMILES format may not support multiple descriptors in parentheses.
#    Consider using atom class notation or manually marking ports.

# %% [markdown]
# ## Step 4: Configure Polymer Builder

# %%
library = {"EO2": eo2, "PS": ps, "EO3": eo3}

# Reaction selectors
def select_carbon_from_oh(assembly: Atomistic, port_name: str):
    """Select C atom connected to -OH oxygen."""
    port_o = select_port_atom(assembly, port_name)
    c_neighbors = find_neighbors(assembly, port_o, element="C")
    if not c_neighbors:
        raise ValueError(f"No C neighbor for -OH at port {port_name}")
    return c_neighbors[0]

def select_h_from_oh(assembly: Atomistic, port_atom):
    """Select H from -OH group."""
    if port_atom["symbol"] != "O":
        raise ValueError(f"Expected O, got {port_atom['symbol']}")
    h_neighbors = find_neighbors(assembly, port_atom, element="H")
    if not h_neighbors:
        raise ValueError("No H found bonded to -OH")
    return [h_neighbors[0]]

dehydration_reacter = Reacter(
    name="dehydration_ether_formation",
    port_selector_left=select_carbon_from_oh,
    port_selector_right=select_port_atom,
    leaving_selector_left=select_hydroxyl_group,
    leaving_selector_right=select_h_from_oh,
    bond_former=form_single_bond,
)

# Port map
port_map = {}
for left_label in library.keys():
    for right_label in library.keys():
        port_map[(left_label, right_label)] = ("$", "$")

connector = ReacterConnector(default=dehydration_reacter, port_map=port_map)
placer = Placer(separator=CovalentSeparator(), orienter=LinearOrienter())
builder = PolymerBuilder(library=library, connector=connector, placer=placer, typifier=typifier)

print("✅ Polymer builder configured")
print(f"   Library: {list(library.keys())}")
# Out:
# ✅ Polymer builder configured
#    Library: ['EO2', 'PS', 'EO3']

# %% [markdown]
# ## Step 5: Helper Functions

# %%
output_dir = Path("case1_output")
output_dir.mkdir(parents=True, exist_ok=True)

def export_to_lammps(structure: Atomistic, filepath: Path):
    """Export structure to LAMMPS data format."""
    frame = structure.to_frame()
    if "atoms" in frame:
        atoms = frame["atoms"]
        n_atoms = atoms.nrows
        if "mol" not in atoms:
            atoms["mol"] = np.ones(n_atoms, dtype=int)
        if "q" not in atoms:
            atoms["q"] = np.zeros(n_atoms, dtype=float)
    writer = LammpsDataWriter(filepath)
    writer.write(frame)

# %% [markdown]
# ## Example 1: Linear Polymer
#
# Build a linear chain: `{[#EO2]|4[#PS]}`

# %%
cgsmiles_linear = "{[#EO2]|4[#PS]}"
print(f"Building: {cgsmiles_linear}")

build_result = builder.build(cgsmiles_linear)
chain = build_result.polymer

print(f"✅ Built successfully:")
print(f"   Atoms: {len(chain.atoms)}")
print(f"   Bonds: {len(chain.bonds)}")
print(f"   Connection steps: {build_result.total_steps}")

export_to_lammps(chain, output_dir / "linear.data")
print(f"   Exported to {output_dir}/linear.data")
# Out:
# Building: {[#EO2]|4[#PS]}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 cgsmiles_linear = "{[#EO2]|4[#PS]}"
#       2 print(f"Building: {cgsmiles_linear}")
# ----> 4 build_result = builder.build(cgsmiles_linear)
#       5 chain = build_result.polymer
#       7 print(f"✅ Built successfully:")
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:90, in PolymerBuilder.build(self, cgsmiles)
#      87 self._validate_ir(ir)
#      89 # Build polymer from graph
# ---> 90 polymer, history = self._build_from_graph(ir.base_graph)
#      92 return PolymerBuildResult(
#      93     polymer=polymer,
#      94     connection_history=history,
#      95     total_steps=len(history),
#      96 )
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:150, in PolymerBuilder._build_from_graph(self, graph)
#     147 root_node = graph.nodes[0]
#     149 # Connect all edges using DFS
# --> 150 self._dfs_connect(
#     151     graph=graph,
#     152     node=root_node,
#     153     adjacency=adjacency,
#     154     monomers=monomers,
#     155     visited_edges=visited_edges,
#     156     connection_history=connection_history,
#     157 )
#     159 # Return the monomer of the root node (which now contains the entire polymer)
#     160 return monomers[root_node.id], connection_history
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:319, in PolymerBuilder._dfs_connect(self, graph, node, adjacency, monomers, visited_edges, connection_history)
#     316     monomers[nid] = merged
#     318 # Recursively connect neighbors
# --> 319 self._dfs_connect(
#     320     graph=graph,
#     321     node=neighbor_node,
#     322     adjacency=adjacency,
#     323     monomers=monomers,
#     324     visited_edges=visited_edges,
#     325     connection_history=connection_history,
#     326 )
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:319, in PolymerBuilder._dfs_connect(self, graph, node, adjacency, monomers, visited_edges, connection_history)
#     316     monomers[nid] = merged
#     318 # Recursively connect neighbors
# --> 319 self._dfs_connect(
#     320     graph=graph,
#     321     node=neighbor_node,
#     322     adjacency=adjacency,
#     323     monomers=monomers,
#     324     visited_edges=visited_edges,
#     325     connection_history=connection_history,
#     326 )
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:303, in PolymerBuilder._dfs_connect(self, graph, node, adjacency, monomers, visited_edges, connection_history)
#     300 neighbor_group = [nid for nid, mon in monomers.items() if mon is neighbor_monomer]
#     302 # Connect them using node IDs for precise port location
# --> 303 merged = self._connect_monomers(
#     304     left=current_monomer,
#     305     right=neighbor_monomer,
#     306     left_label=node.label,
#     307     right_label=neighbor_node.label,
#     308     left_node_id=node_id,
#     309     right_node_id=neighbor_id,
#     310     bond_order=bond_order,
#     311     connection_history=connection_history,
#     312 )
#     314 # Update ALL nodes in both groups to point to the merged result
#     315 for nid in current_group + neighbor_group:
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:422, in PolymerBuilder._connect_monomers(self, left, right, left_label, right_label, left_node_id, right_node_id, bond_order, connection_history)
#     416 right_port_targets: dict[str, list[Atom]] = {
#     417     name: [port.target for port in port_list]
#     418     for name, port_list in right_ports.items()
#     419 }
#     421 # Execute connection
# --> 422 connection_result = self.connector.connect(
#     423     left,
#     424     right,
#     425     left_label,
#     426     right_label,
#     427     left_port_name,
#     428     right_port_name,
#     429     typifier=self.typifier,
#     430 )
#     432 product = connection_result.product
#     433 metadata = connection_result.metadata
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/connectors.py:509, in ReacterConnector.connect(self, left, right, left_type, right_type, port_L, port_R, typifier)
#     506 reacter = self.get_reacter(left_type, right_type)
#     508 # Execute reaction
# --> 509 product_set: ReactionResult = reacter.run(
#     510     left,
#     511     right,
#     512     port_L=port_L,
#     513     port_R=port_R,
#     514     compute_topology=True,
#     515     typifier=typifier,
#     516 )
#     518 # Store in history
#     519 self._history.append(product_set)
#
# File /workspaces/molcrafts/molpy/src/molpy/reacter/base.py:536, in Reacter.run(self, left, right, port_L, port_R, compute_topology, record_intermediates, typifier)
#     533 port_atom_L = self.port_selector_left(left_copy, port_L)
#     534 port_atom_R = self.port_selector_right(right_copy, port_R)
# --> 536 leaving_L = self.leaving_selector_left(left_copy, port_atom_L)
#     537 leaving_R = self.leaving_selector_right(right_copy, port_atom_R)
#     539 # Step 3: Merge structures
#
# File /workspaces/molcrafts/molpy/src/molpy/reacter/selectors.py:181, in select_hydroxyl_group(assembly, port_atom)
#     179 h_neighbors = find_neighbors(assembly, hydroxyl_o, element="H")
#     180 if not h_neighbors:
# --> 181     raise ValueError("No hydrogen found bonded to hydroxyl oxygen")
#     183 return [hydroxyl_o, h_neighbors[0]]
#
# ValueError: No hydrogen found bonded to hydroxyl oxygen

# %% [markdown]
# ## Example 2: Cyclic (Ring) Polymer
#
# Build a cyclic polymer: `{[#EO2]1[#PS][#EO2][#PS][#EO2]1}`

# %%
cgsmiles_ring = "{[#EO2]1[#PS][#EO2][#PS][#EO2]1}"
print(f"Building: {cgsmiles_ring}")

build_result = builder.build(cgsmiles_ring)
ring_chain = build_result.polymer

print(f"✅ Ring polymer built:")
print(f"   Atoms: {len(ring_chain.atoms)}")
print(f"   Bonds: {len(ring_chain.bonds)}")
print(f"   Connection steps: {build_result.total_steps}")
    
export_to_lammps(ring_chain, output_dir / "ring.data")
print(f"   Exported to {output_dir}/ring.data")
# Out:
# Building: {[#EO2]1[#PS][#EO2][#PS][#EO2]1}
# ✅ Ring polymer built:
#    Atoms: 73
#    Bonds: 75
#    Connection steps: 5
#    Exported to case1_output/ring.data

# %% [markdown]
# ## Example 3: Branched Polymer
#
# Build a branched structure: `{[#PS][#EO3]([#PS])([#PS])}`
#
# This requires the 3-arm monomer (EO3) which has 3 ports. The branch point connects to 3 neighbors.

# %%
cgsmiles_branch = "{[#PS][#EO3]([#PS])([#PS])}"
print(f"Building: {cgsmiles_branch}")

# Show graph structure
ir_branch = parse_cgsmiles(cgsmiles_branch)

build_result = builder.build(cgsmiles_branch)
branch_chain = build_result.polymer

print(f"\n✅ Branch polymer built:")
print(f"   Atoms: {len(branch_chain.atoms)}")
print(f"   Bonds: {len(branch_chain.bonds)}")
print(f"   Connection steps: {build_result.total_steps}")
    
export_to_lammps(branch_chain, output_dir / "branch.data")
print(f"   Exported to {output_dir}/branch.data")
# Out:
# Building: {[#PS][#EO3]([#PS])([#PS])}
#    Graph: 4 nodes, 3 bonds
#    Branch point: Node [EO3] has 3 connections
# ---------------------------------------------------------------------------
# NoCompatiblePortsError                    Traceback (most recent call last)
# Cell In[8], line 18
#      15     if count > 2:
#      16         print(f"   Branch point: Node [{node_label}] has {count} connections")
# ---> 18 build_result = builder.build(cgsmiles_branch)
#      19 branch_chain = build_result.polymer
#      21 print(f"\n✅ Branch polymer built:")
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:90, in PolymerBuilder.build(self, cgsmiles)
#      87 self._validate_ir(ir)
#      89 # Build polymer from graph
# ---> 90 polymer, history = self._build_from_graph(ir.base_graph)
#      92 return PolymerBuildResult(
#      93     polymer=polymer,
#      94     connection_history=history,
#      95     total_steps=len(history),
#      96 )
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:150, in PolymerBuilder._build_from_graph(self, graph)
#     147 root_node = graph.nodes[0]
#     149 # Connect all edges using DFS
# --> 150 self._dfs_connect(
#     151     graph=graph,
#     152     node=root_node,
#     153     adjacency=adjacency,
#     154     monomers=monomers,
#     155     visited_edges=visited_edges,
#     156     connection_history=connection_history,
#     157 )
#     159 # Return the monomer of the root node (which now contains the entire polymer)
#     160 return monomers[root_node.id], connection_history
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:317, in PolymerBuilder._dfs_connect(self, graph, node, adjacency, monomers, visited_edges, connection_history)
#     314     monomers[nid] = merged
#     316 # Recursively connect neighbors
# --> 317 self._dfs_connect(
#     318     graph=graph,
#     319     node=neighbor_node,
#     320     adjacency=adjacency,
#     321     monomers=monomers,
#     322     visited_edges=visited_edges,
#     323     connection_history=connection_history,
#     324 )
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:301, in PolymerBuilder._dfs_connect(self, graph, node, adjacency, monomers, visited_edges, connection_history)
#     298 neighbor_group = [nid for nid, mon in monomers.items() if mon is neighbor_monomer]
#     300 # Connect them using node IDs for precise port location
# --> 301 merged = self._connect_monomers(
#     302     left=current_monomer,
#     303     right=neighbor_monomer,
#     304     left_label=node.label,
#     305     right_label=neighbor_node.label,
#     306     left_node_id=node_id,
#     307     right_node_id=neighbor_id,
#     308     bond_order=bond_order,
#     309     connection_history=connection_history,
#     310 )
#     312 # Update ALL nodes in both groups to point to the merged result
#     313 for nid in current_group + neighbor_group:
#
# File /workspaces/molcrafts/molpy/src/molpy/builder/polymer/polymer_builder.py:363, in PolymerBuilder._connect_monomers(self, left, right, left_label, right_label, left_node_id, right_node_id, bond_order, connection_history)
#     360 right_ports = self._find_ports_on_node(right, right_node_id)
#     362 if not left_ports:
# --> 363     raise NoCompatiblePortsError(
#     364         f"Node {left_node_id} (label '{left_label}') has no available ports"
#     365     )
#     366 if not right_ports:
#     367     raise NoCompatiblePortsError(
#     368         f"Node {right_node_id} (label '{right_label}') has no available ports"
#     369     )
#
# NoCompatiblePortsError: Node 47 (label 'EO3') has no available ports
